# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#----------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Đọc dữ liệu của bảng sinh viên**

# %%
df_admission = pd.read_csv("Data/admission.csv")
df_admission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30217 entries, 0 to 30216
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MA_SO_SV         30217 non-null  object
#  1   NAM_TUYENSINH    30217 non-null  int64
#  2   PTXT             30217 non-null  object
#  3   TOHOP_XT         30217 non-null  object
#  4   DIEM_TRUNGTUYEN  30217 non-null  float64
#  5   DIEM_CHUAN       30217 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df_admission.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Đọc dữ liệu bảng học tập**

# %%
df_academic_records = pd.read_csv("Data/academic_records.csv")
df_academic_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105726 entries, 0 to 105725
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   MA_SO_SV      105726 non-null  object
#  1   HOC_KY        105726 non-null  object
#  2   CPA           105726 non-null  float64
#  3   GPA           105726 non-null  float64
#  4   TC_DANGKY     105726 non-null  int64
#  5   TC_HOANTHANH  105726 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ MB

# %%
df_academic_records.describe()
# Out:
#                  CPA            GPA      TC_DANGKY   TC_HOANTHANH
# count  105726.000000  105726.000000  105726.000000  105726.000000
# mean        1.962662       2.290328      19.438492      15.609916
# std         0.899984       0.479314       5.584857       6.610703
# min         0.000000       0.000000       1.000000       0.000000
# 25%         1.360000       1.980000      17.000000      12.000000
# 50%         2.000000       2.250000      20.000000      16.000000
# 75%         2.600000       2.570000      22.000000      20.000000
# max         4.080000       4.080000      71.000000      65.000000

# %% [markdown]
# **Gộp 2 bảng lại với nhau**

# %%
df_full = df_academic_records.merge(df_admission, how="left", on="MA_SO_SV")
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105726 entries, 0 to 105725
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   MA_SO_SV         105726 non-null  object
#  1   HOC_KY           105726 non-null  object
#  2   CPA              105726 non-null  float64
#  3   GPA              105726 non-null  float64
#  4   TC_DANGKY        105726 non-null  int64
#  5   TC_HOANTHANH     105726 non-null  int64
#  6   NAM_TUYENSINH    105726 non-null  int64
#  7   PTXT             105726 non-null  object
#  8   TOHOP_XT         105726 non-null  object
#  9   DIEM_TRUNGTUYEN  105726 non-null  float64
#  10  DIEM_CHUAN       105726 non-null  float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 8.9+ MB

# %%
df_full.head()
# Out:
#        MA_SO_SV         HOC_KY   CPA   GPA  TC_DANGKY  TC_HOANTHANH  \
# 0  f022ed8d1ac1  HK2 2020-2021  2.19  2.02         18            18
# 1  f022ed8d1ac1  HK1 2022-2023  0.95  2.12         14             7
# 2  f022ed8d1ac1  HK1 2023-2024  0.81  1.89         29            16
# 3  f022ed8d1ac1  HK2 2022-2023  1.37  1.93         26            23
# 4  f022ed8d1ac1  HK2 2023-2024  1.71  1.91         16            13
#
#    NAM_TUYENSINH PTXT TOHOP_XT  DIEM_TRUNGTUYEN  DIEM_CHUAN
# 0           2020    1      A00            23.96       21.72
# 1           2020    1      A00            23.96       21.72
# 2           2020    1      A00            23.96       21.72
# 3           2020    1      A00            23.96       21.72
# 4           2020    1      A00            23.96       21.72

# %%
df_full.duplicated().sum()
# Out:
# 24

# %%
df_full.drop_duplicates(keep = 'first', inplace= True)

# %%
df_full["PTXT"] = df_full["PTXT"].astype('int64')

# %%
df_full["TI_LE_HOAN_THANH"] =  df_full["TC_HOANTHANH"] / df_full["TC_DANGKY"]

# %%
df_full["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK1 2023-2024    17075
# HK1 2022-2023    15486
# HK2 2023-2024    15144
# HK2 2022-2023    14504
# HK1 2021-2022    12698
# HK2 2021-2022    12434
# HK1 2020-2021     9186
# HK2 2020-2021     9175
# Name: count, dtype: int64

# %%
def layNamHoc(x):
    return x.split(" ")[1].split("-")[0]

def layNam(x):
    res =  int(x.split(" ")[1].split("-")[0]) + int(x.split(" ")[0][-1]) - 1
    return res
    
def layHocKi(x):
    return x.split(" ")[0][-1]
# 2020-03 đến 2022-06 = 1
def covidProid(x):
    covid = ["HK2 2020-2021", "HK1 2021-2022", "HK2 2021-2022"]
    if x in covid:
        return 1
    return 0

# %%
df_full["NAM_HOC"] = df_full["HOC_KY"].apply( lambda x : f"{layNamHoc(x)}").astype(int)
df_full["NAM"] = df_full["HOC_KY"].apply( lambda x : f"{layNam(x)}").astype(int)
df_full["SO_HOC_KY"] = df_full["HOC_KY"].apply( lambda x : f"{layHocKi(x)}").astype(int)
df_full["SO_HOC_KY"] = (df_full["NAM_HOC"] - df_full["NAM_TUYENSINH"])*2  + df_full["SO_HOC_KY"]
df_full["KHOANG_CACH_TRUNG_TUYEN"] = df_full["DIEM_TRUNGTUYEN"] - df_full["DIEM_CHUAN"]
# df_full["TAC_DONG_THIEN"] = df_full["HOC_KY"].apply(lambda x: f"{covidProid(x)}")

# %%
# Học phí 2020 - 11.7 trieu dong/nam
# Học phí 2021 - 12.7 trieu dong/nam
# Học phí 2022 - 13.7 trieu dong/nam
# Học phí 2023 - 15.2 trieu dong/nam
dfBS = pd.read_excel("Data/BO SUNG.xlsx")
dfBS.head()
# Out:
#           HOC_KY   Unnamed: 1  TAC_DONG_TU_NHIEN  HOC_PHI_TRUNG_BINH  \
# 0  HK1 2020-2021  17/8 - 15/1                  1                  18
# 1  HK2 2020-2021  20/1 - 28/6                  1                  18
# 2  HK1 2021-2022  17/8 - 15/1                  1                  18
# 3  HK2 2021-2022  20/1 - 28/6                  0                  18
# 4  HK1 2022-2023  17/8 - 15/1                  0                  18
#
#    TY_LE_THAT_NGHIEP   NAM
# 0             15.428  2020
# 1             14.429  2021
# 2                NaN  2021
# 3             16.192  2022
# 4                NaN  2022

# %%
dfBS1 = dfBS.loc[:,["HOC_KY","TAC_DONG_TU_NHIEN","HOC_PHI_TRUNG_BINH"]]
dfBS1.head()
# Out:
#           HOC_KY  TAC_DONG_TU_NHIEN  HOC_PHI_TRUNG_BINH
# 0  HK1 2020-2021                  1                  18
# 1  HK2 2020-2021                  1                  18
# 2  HK1 2021-2022                  1                  18
# 3  HK2 2021-2022                  0                  18
# 4  HK1 2022-2023                  0                  18

# %%
dfBS2 = dfBS.loc[:,['TY_LE_THAT_NGHIEP','NAM']]
# Ban đầu
dfBS2.head(10)
# Out:
#    TY_LE_THAT_NGHIEP   NAM
# 0             15.428  2020
# 1             14.429  2021
# 2                NaN  2021
# 3             16.192  2022
# 4                NaN  2022
# 5             16.944  2023
# 6                NaN  2023
# 7             14.964  2024

# %%
# sau khi lọc những Row null ở Tỷ lệ thất nghiệp
dfBS2 = dfBS2[dfBS2["TY_LE_THAT_NGHIEP"].notnull()]
dfBS2.head(10)

df_full = df_full.merge(dfBS1, how="left", on="HOC_KY")
df_full = df_full.merge(dfBS2, how="left", on="NAM")

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105702 entries, 0 to 105701
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MA_SO_SV                 105702 non-null  object
#  1   HOC_KY                   105702 non-null  object
#  2   CPA                      105702 non-null  float64
#  3   GPA                      105702 non-null  float64
#  4   TC_DANGKY                105702 non-null  int64
#  5   TC_HOANTHANH             105702 non-null  int64
#  6   NAM_TUYENSINH            105702 non-null  int64
#  7   PTXT                     105702 non-null  int64
#  8   TOHOP_XT                 105702 non-null  object
#  9   DIEM_TRUNGTUYEN          105702 non-null  float64
#  10  DIEM_CHUAN               105702 non-null  float64
#  11  TI_LE_HOAN_THANH         105702 non-null  float64
#  12  NAM_HOC                  105702 non-null  int32
#  13  NAM                      105702 non-null  int32
#  14  SO_HOC_KY                105702 non-null  int64
#  15  KHOANG_CACH_TRUNG_TUYEN  105702 non-null  float64
#  16  TAC_DONG_TU_NHIEN        105702 non-null  int64
#  17  HOC_PHI_TRUNG_BINH       105702 non-null  int64
#  18  TY_LE_THAT_NGHIEP        105702 non-null  float64
# dtypes: float64(7), int32(2), int64(7), object(3)
# memory usage: 14.5+ MB

# %%
df_full.head()
# Out:
#        MA_SO_SV         HOC_KY   CPA   GPA  TC_DANGKY  TC_HOANTHANH  \
# 0  f022ed8d1ac1  HK2 2020-2021  2.19  2.02         18            18
# 1  f022ed8d1ac1  HK1 2022-2023  0.95  2.12         14             7
# 2  f022ed8d1ac1  HK1 2023-2024  0.81  1.89         29            16
# 3  f022ed8d1ac1  HK2 2022-2023  1.37  1.93         26            23
# 4  f022ed8d1ac1  HK2 2023-2024  1.71  1.91         16            13
#
#    NAM_TUYENSINH  PTXT TOHOP_XT  DIEM_TRUNGTUYEN  DIEM_CHUAN  \
# 0           2020     1      A00            23.96       21.72
# 1           2020     1      A00            23.96       21.72
# 2           2020     1      A00            23.96       21.72
# 3           2020     1      A00            23.96       21.72
# 4           2020     1      A00            23.96       21.72
#
#    TI_LE_HOAN_THANH  NAM_HOC   NAM  SO_HOC_KY  KHOANG_CACH_TRUNG_TUYEN  \
# 0          1.000000     2020  2021          2                     2.24
# 1          0.500000     2022  2022          5                     2.24
# 2          0.551724     2023  2023          7                     2.24
# 3          0.884615     2022  2023          6                     2.24
# 4          0.812500     2023  2024          8                     2.24
#
#    TAC_DONG_TU_NHIEN  HOC_PHI_TRUNG_BINH  TY_LE_THAT_NGHIEP
# 0                  1                  18             14.429
# 1                  0                  18             16.192
# 2                  1                  20             16.944
# 3                  0                  18             16.944
# 4                  0                  22             14.964

# %%
df_full["NAM"].value_counts().sort_index()
# Out:
# NAM
# 2020     9186
# 2021    21873
# 2022    27920
# 2023    31579
# 2024    15144
# Name: count, dtype: int64

# %%
df_full["NAM_TUYENSINH"].value_counts().sort_index()
# Out:
# NAM_TUYENSINH
# 2018    16737
# 2019    21292
# 2020    24975
# 2021    21381
# 2022    14192
# 2023     7125
# Name: count, dtype: int64

# %%
df_full.describe()
# Out:
#                  CPA            GPA      TC_DANGKY   TC_HOANTHANH  \
# count  105702.000000  105702.000000  105702.000000  105702.000000
# mean        1.962646       2.290318      19.438204      15.609591
# std         0.899974       0.479302       5.585337       6.610654
# min         0.000000       0.000000       1.000000       0.000000
# 25%         1.360000       1.980000      17.000000      12.000000
# 50%         2.000000       2.250000      20.000000      16.000000
# 75%         2.600000       2.570000      22.000000      20.000000
# max         4.080000       4.080000      71.000000      65.000000
#
#        NAM_TUYENSINH           PTXT  DIEM_TRUNGTUYEN     DIEM_CHUAN  \
# count  105702.000000  105702.000000    105702.000000  105702.000000
# mean     2020.154907      22.842482        22.044500      20.020546
# std         1.468610      49.639620         2.651235       2.963702
# min      2018.000000       1.000000         0.000000       0.000000
# 25%      2019.000000       1.000000        20.160000      17.570000
# 50%      2020.000000       1.000000        22.380000      19.800000
# 75%      2021.000000       1.000000        24.080000      22.200000
# max      2023.000000     500.000000        59.060000      50.880000
#
#        TI_LE_HOAN_THANH        NAM_HOC            NAM      SO_HOC_KY  \
# count     105702.000000  105702.000000  105702.000000  105702.000000
# mean           0.803579    2021.719636    2022.204556       4.614378
# std            0.259950       1.076476       1.176672       2.660478
# min            0.000000    2020.000000    2020.000000       1.000000
# 25%            0.705882    2021.000000    2021.000000       2.000000
# 50%            0.900000    2022.000000    2022.000000       4.000000
# 75%            1.000000    2023.000000    2023.000000       6.000000
# max            1.000000    2023.000000    2024.000000      12.000000
#
#        KHOANG_CACH_TRUNG_TUYEN  TAC_DONG_TU_NHIEN  HOC_PHI_TRUNG_BINH  \
# count            105702.000000      105702.000000       105702.000000
# mean                  2.023955           0.455375           18.896161
# std                   1.792214           0.498007            1.461302
# min                   0.000000           0.000000           18.000000
# 25%                   0.640000           0.000000           18.000000
# 50%                   1.530000           0.000000           18.000000
# 75%                   2.940000           1.000000           20.000000
# max                  10.900000           1.000000           22.000000
#
#        TY_LE_THAT_NGHIEP
# count      105702.000000
# mean           15.809513
# std             0.965718
# min            14.429000
# 25%            14.964000
# 50%            16.192000
# 75%            16.944000
# max            16.944000

# %%
# Xử lý ngoại lai CPA , GPA > 4.0
df_full.loc[df_full['GPA'] > 4, 'GPA'] = 4
df_full.loc[df_full['CPA'] > 4, 'CPA'] = 4

# %%
df_full.describe()
# Out:
#                  CPA            GPA      TC_DANGKY   TC_HOANTHANH  \
# count  105702.000000  105702.000000  105702.000000  105702.000000
# mean        1.962450       2.290285      19.438204      15.609591
# std         0.899524       0.479183       5.585337       6.610654
# min         0.000000       0.000000       1.000000       0.000000
# 25%         1.360000       1.980000      17.000000      12.000000
# 50%         2.000000       2.250000      20.000000      16.000000
# 75%         2.600000       2.570000      22.000000      20.000000
# max         4.000000       4.000000      71.000000      65.000000
#
#        NAM_TUYENSINH           PTXT  DIEM_TRUNGTUYEN     DIEM_CHUAN  \
# count  105702.000000  105702.000000    105702.000000  105702.000000
# mean     2020.154907      22.842482        22.044500      20.020546
# std         1.468610      49.639620         2.651235       2.963702
# min      2018.000000       1.000000         0.000000       0.000000
# 25%      2019.000000       1.000000        20.160000      17.570000
# 50%      2020.000000       1.000000        22.380000      19.800000
# 75%      2021.000000       1.000000        24.080000      22.200000
# max      2023.000000     500.000000        59.060000      50.880000
#
#        TI_LE_HOAN_THANH        NAM_HOC            NAM      SO_HOC_KY  \
# count     105702.000000  105702.000000  105702.000000  105702.000000
# mean           0.803579    2021.719636    2022.204556       4.614378
# std            0.259950       1.076476       1.176672       2.660478
# min            0.000000    2020.000000    2020.000000       1.000000
# 25%            0.705882    2021.000000    2021.000000       2.000000
# 50%            0.900000    2022.000000    2022.000000       4.000000
# 75%            1.000000    2023.000000    2023.000000       6.000000
# max            1.000000    2023.000000    2024.000000      12.000000
#
#        KHOANG_CACH_TRUNG_TUYEN  TAC_DONG_TU_NHIEN  HOC_PHI_TRUNG_BINH  \
# count            105702.000000      105702.000000       105702.000000
# mean                  2.023955           0.455375           18.896161
# std                   1.792214           0.498007            1.461302
# min                   0.000000           0.000000           18.000000
# 25%                   0.640000           0.000000           18.000000
# 50%                   1.530000           0.000000           18.000000
# 75%                   2.940000           1.000000           20.000000
# max                  10.900000           1.000000           22.000000
#
#        TY_LE_THAT_NGHIEP
# count      105702.000000
# mean           15.809513
# std             0.965718
# min            14.429000
# 25%            14.964000
# 50%            16.192000
# 75%            16.944000
# max            16.944000

# %%
plt.figure(figsize=(19, 20))
plt.subplot(3,1,1)
plt.plot(
     df_full.groupby("NAM_TUYENSINH")["KHOANG_CACH_TRUNG_TUYEN"].max().index,
     df_full.groupby("NAM_TUYENSINH")["KHOANG_CACH_TRUNG_TUYEN"].max().values,
    linestyle = "--",
    marker = 'd',
    label = "Max"
)
plt.plot(
     df_full.groupby("NAM_TUYENSINH")["KHOANG_CACH_TRUNG_TUYEN"].mean().index,
     df_full.groupby("NAM_TUYENSINH")["KHOANG_CACH_TRUNG_TUYEN"].mean().values,
    linestyle = "--",
    marker = 'd',
    label = "Min"
    
)
plt.grid(ls = "--")
plt.title("BIỂU ĐỒ KHOẢNG CÁCH ĐIỂM TRÚNG TUYỂN VỚI ĐIỂM THI")
plt.legend()


plt.subplot(3,1,2)
bar_PTXT = plt.bar(
   df_full["PTXT"].value_counts().index,
    df_full["PTXT"].value_counts().values,
)

for bar in bar_PTXT:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f'{height:.0f}',
        ha='center', va='bottom'
    )
plt.grid(ls = "--")
plt.title("BIỂU ĐỒ SỐ LƯỢNG SINH VIÊN THEO PHƯƠNG THỨC XÉT TUYỂN")


plt.subplot(3,1,3)
bar_TOHOP_XT = plt.bar(
   df_full["TOHOP_XT"].value_counts().index,
    df_full["TOHOP_XT"].value_counts().values,
)

for bar in bar_TOHOP_XT:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f'{height:.0f}',
        ha='center', va='bottom'
    )

plt.grid(ls = "--")
plt.title("BIỂU ĐỒ SỐ LƯỢNG SINH VIÊN THEO TỔ HỢP XÉT TUYỂN")


plt.show()

# %%
df_full["PTXT"].value_counts()
# Out:
# PTXT
# 1      84294
# 100    20665
# 409      455
# 402       82
# 500       71
# 3         56
# 200       44
# 5         35
# Name: count, dtype: int64

# %%
df_admission["PTXT"].value_counts()
# Out:
# PTXT
# 1          13712
# 100        11922
# 200         4201
# 402          193
# 409          142
# 500           20
# 3             11
# 5              9
# 417            3
# 303            2
# 402_SPT        1
# 415            1
# Name: count, dtype: int64

# %% [markdown]
# # CHIA TẬP DỮ LIỆU THÀNH CÁC NĂM NHẬP HỌC

# %%
#vẼ BIỀU ĐỒ CẦN THIẾT
def veBieuDo(data):
    plt.figure(figsize=(15,6))

    demSinhVienTungHocKi = data.groupby("SO_HOC_KY")["TI_LE_HOAN_THANH"].mean()
    print("Tỉ lệ qua môn:")
    print(demSinhVienTungHocKi)
    plt.subplot(2,2,1)
    plt.plot(
        demSinhVienTungHocKi.index,
        demSinhVienTungHocKi.values,
        linestyle = "--",
        marker = 'd'
    )
    plt.grid(ls = "--")
    plt.title("TỈ LỆ HOÀN THÀNH MÔN TRUNG BÌNH CỦA SINH VIÊN THEO KÌ HỌC")

    luongSinhVienTungHocKi = data.groupby("SO_HOC_KY")["TI_LE_HOAN_THANH"].count()
    print("Lượng sinh viên:")
    print(luongSinhVienTungHocKi)
    
    plt.subplot(2,2,2)
    plt.plot(
        luongSinhVienTungHocKi.index,
        luongSinhVienTungHocKi.values,
        linestyle = "--",
        marker = 'd',
        c = "red"
    )
    plt.grid(ls = "--")
    plt.title("LƯỢNG SINH VIÊN THEO KÌ HỌC")


    luongSinhVienTungHocKi = data.groupby("SO_HOC_KY")["TI_LE_HOAN_THANH"].count()
    print("Lượng sinh viên:")
    print(luongSinhVienTungHocKi)
    
    plt.subplot(2,2,2)
    plt.plot(
        luongSinhVienTungHocKi.index,
        luongSinhVienTungHocKi.values,
        linestyle = "--",
        marker = 'd',
        c = "red"
    )
    plt.grid(ls = "--")
    plt.title("LƯỢNG SINH VIÊN THEO TỪNG KÌ HỌC")

    
    plt.show()

# %% [markdown]
# ## Năm 2018

# %%
df_full["NAM_TUYENSINH"] == 2018
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 105697    False
# 105698    False
# 105699    False
# 105700    False
# 105701    False
# Name: NAM_TUYENSINH, Length: 105702, dtype: bool

# %%
df_2018 = df_full[df_full["NAM_TUYENSINH"] == 2018]
df_2018["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK2 2020-2021    2837
# HK1 2020-2021    2833
# HK1 2021-2022    2745
# HK2 2021-2022    2681
# HK1 2022-2023    2552
# HK2 2022-2023    1743
# HK1 2023-2024     791
# HK2 2023-2024     555
# Name: count, dtype: int64

# %%
veBieuDo(df_2018)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 5     0.786454
# 6     0.803597
# 7     0.854185
# 8     0.824725
# 9     0.835215
# 10    0.827392
# 11    0.670088
# 12    0.644704
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 5     2833
# 6     2837
# 7     2745
# 8     2681
# 9     2552
# 10    1743
# 11     791
# 12     555
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 5     2833
# 6     2837
# 7     2745
# 8     2681
# 9     2552
# 10    1743
# 11     791
# 12     555
# Name: TI_LE_HOAN_THANH, dtype: int64

# %% [markdown]
# ## Năm 2019

# %%
df_2019 = df_full[df_full["NAM_TUYENSINH"] == 2019]
df_2019["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK1 2020-2021    2987
# HK2 2020-2021    2964
# HK1 2021-2022    2926
# HK2 2021-2022    2861
# HK1 2022-2023    2754
# HK2 2022-2023    2681
# HK1 2023-2024    2527
# HK2 2023-2024    1592
# Name: count, dtype: int64

# %%
veBieuDo(df_2019)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 3     0.743905
# 4     0.814659
# 5     0.854046
# 6     0.777250
# 7     0.796474
# 8     0.844661
# 9     0.832847
# 10    0.774280
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 3     2987
# 4     2964
# 5     2926
# 6     2861
# 7     2754
# 8     2681
# 9     2527
# 10    1592
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 3     2987
# 4     2964
# 5     2926
# 6     2861
# 7     2754
# 8     2681
# 9     2527
# 10    1592
# Name: TI_LE_HOAN_THANH, dtype: int64

# %% [markdown]
# ## Năm 2020

# %%
df_2020 = df_full[df_full["NAM_TUYENSINH"] == 2020]
df_2020["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK2 2020-2021    3374
# HK1 2020-2021    3366
# HK1 2021-2022    3247
# HK2 2021-2022    3144
# HK1 2022-2023    3061
# HK2 2022-2023    2997
# HK1 2023-2024    2987
# HK2 2023-2024    2799
# Name: count, dtype: int64

# %%
veBieuDo(df_2020)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 1    0.745181
# 2    0.830962
# 3    0.857700
# 4    0.797256
# 5    0.744357
# 6    0.768426
# 7    0.820040
# 8    0.768933
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3366
# 2    3374
# 3    3247
# 4    3144
# 5    3061
# 6    2997
# 7    2987
# 8    2799
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3366
# 2    3374
# 3    3247
# 4    3144
# 5    3061
# 6    2997
# 7    2987
# 8    2799
# Name: TI_LE_HOAN_THANH, dtype: int64

# %% [markdown]
# ## Năm 2021

# %%
df_2021 = df_full[df_full["NAM_TUYENSINH"] == 2021]
df_2021["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK1 2021-2022    3780
# HK2 2021-2022    3748
# HK1 2022-2023    3548
# HK2 2022-2023    3516
# HK1 2023-2024    3425
# HK2 2023-2024    3364
# Name: count, dtype: int64

# %%
veBieuDo(df_2021)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 1    0.939200
# 2    0.788930
# 3    0.792148
# 4    0.773292
# 5    0.801261
# 6    0.815342
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3780
# 2    3748
# 3    3548
# 4    3516
# 5    3425
# 6    3364
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3780
# 2    3748
# 3    3548
# 4    3516
# 5    3425
# 6    3364
# Name: TI_LE_HOAN_THANH, dtype: int64

# %% [markdown]
# ## Năm 2022

# %%
df_2022 = df_full[df_full["NAM_TUYENSINH"] == 2022]
df_2022["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK1 2023-2024    3724
# HK1 2022-2023    3571
# HK2 2022-2023    3567
# HK2 2023-2024    3330
# Name: count, dtype: int64

# %%
veBieuDo(df_2022)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 1    0.846278
# 2    0.771528
# 3    0.807916
# 4    0.789890
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3571
# 2    3567
# 3    3724
# 4    3330
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3571
# 2    3567
# 3    3724
# 4    3330
# Name: TI_LE_HOAN_THANH, dtype: int64

# %% [markdown]
# ## Năm 2023

# %%
df_2023 = df_full[df_full["NAM_TUYENSINH"] == 2023]
df_2023["HOC_KY"].value_counts()
# Out:
# HOC_KY
# HK1 2023-2024    3621
# HK2 2023-2024    3504
# Name: count, dtype: int64

# %%
veBieuDo(df_2023)
# Out:
# Tỉ lệ qua môn:
# SO_HOC_KY
# 1    0.811414
# 2    0.741621
# Name: TI_LE_HOAN_THANH, dtype: float64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3621
# 2    3504
# Name: TI_LE_HOAN_THANH, dtype: int64
# Lượng sinh viên:
# SO_HOC_KY
# 1    3621
# 2    3504
# Name: TI_LE_HOAN_THANH, dtype: int64

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105702 entries, 0 to 105701
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MA_SO_SV                 105702 non-null  object
#  1   HOC_KY                   105702 non-null  object
#  2   CPA                      105702 non-null  float64
#  3   GPA                      105702 non-null  float64
#  4   TC_DANGKY                105702 non-null  int64
#  5   TC_HOANTHANH             105702 non-null  int64
#  6   NAM_TUYENSINH            105702 non-null  int64
#  7   PTXT                     105702 non-null  int64
#  8   TOHOP_XT                 105702 non-null  object
#  9   DIEM_TRUNGTUYEN          105702 non-null  float64
#  10  DIEM_CHUAN               105702 non-null  float64
#  11  TI_LE_HOAN_THANH         105702 non-null  float64
#  12  NAM_HOC                  105702 non-null  int32
#  13  NAM                      105702 non-null  int32
#  14  SO_HOC_KY                105702 non-null  int64
#  15  KHOANG_CACH_TRUNG_TUYEN  105702 non-null  float64
#  16  TAC_DONG_TU_NHIEN        105702 non-null  int64
#  17  HOC_PHI_TRUNG_BINH       105702 non-null  int64
#  18  TY_LE_THAT_NGHIEP        105702 non-null  float64
# dtypes: float64(7), int32(2), int64(7), object(3)
# memory usage: 14.5+ MB

# %%
df_full["PTXT"] = df_full["PTXT"].astype('int64')
# for i in df_full["PTXT"].value_counts().index:
#     print(i)

# %%
dict = {}
j = 1
for i in df_full["TOHOP_XT"].value_counts().index:
    dict.update({i:j})
    j+=1

# %%
df_full.replace(dict,inplace=True)

# %%
len(df_full["TOHOP_XT"].value_counts())
# Out:
# 18

# %%
#Save dataset
df_full.to_csv('Data/Data_All.csv', index=None)
df_full.to_excel('Data/Data_All.xlsx', index=None)

# %%
# Save train dataset:  Dữ liệu từ năm học 2020 - 2021 đến hết Học kỳ 1 năm học 2023–2024.
data_train = df_full[df_full["HOC_KY"] != "HK2 2023-2024"]
len(data_train)
data_train.to_csv('Data/Data_Train.csv', index=None)

# %%
#Save test dataset: Dữ liệu Học kỳ 2 năm học 2023–2024.
data_test = df_full[df_full["HOC_KY"] == "HK2 2023-2024"]
len(data_test)
data_test.to_csv('Data/Data_Test.csv', index=None)
